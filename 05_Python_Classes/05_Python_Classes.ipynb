# %% [markdown]
# # [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pmRaul/DA-Python/blob/main/05_Python_Classes/05_Python_Classes.ipynb)

# %% [markdown]
# # Classes in Python 🚀🐍

# %% [markdown]
# In the last post, we talked about `functions` as a way to organize code for reusability and robustness. But sometimes, functions aren’t enough, and that’s where `classes` come in! 🎉 With classes, we can create our own objects, equipped with their own `methods` (functions attached to the object) and `attributes` (properties of the object). Plus, Python’s **inheritance** feature lets us build new objects by reusing and extending existing ones. Cool, right? Let’s dive in! 💡

# %% [markdown]
# ## Defining a Class 🏗️

# %% [markdown]
# To define a class, we use the keyword `class` followed by the name of the class. Inside, we define attributes and methods. Here's an example:

# %%
class MyClass:
    greeting = "Hello!"

    def say_greeting(self):
        print(self.greeting)

# %% [markdown]
# ### Key Points:

# %% [markdown]
# 1. `class`: Used to define a class.
# 2. `MyClass`: The class name (you can name it anything you want!).
# 3. `greeting`: An attribute of the class.
# 4. `say_greeting`: A method that prints the `greeting` attribute.

# %% [markdown]
# ## Creating an Object 🤖

# %% [markdown]
# Once a class is defined, we can create an object (also called an **instance**) from it:

# %%
x = MyClass()

# %% [markdown]
# Now, `x` is an instance of `MyClass`. It inherits all the methods and attributes of the class:

# %%
x.say_greeting()  # Outputs: Hello!
# Out:
# Hello!

# %% [markdown]
# > **Note**: We use `self` inside methods to access attributes and other methods of the class.

# %% [markdown]
# ## Customizing Classes with a Constructor 🛠️

# %% [markdown]
# We use a special method, `__init__`, to initialize attributes when creating an object:

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def greet(self):
        print(f"Hi, {self.name}!")

x = MyClass("Alice")
x.greet()  # Outputs: Hi, Alice!
# Out:
# Hi, Alice!

# %% [markdown]
# ### Explanation:

# %% [markdown]
# - `__init__`: Automatically called when an object is created.
# - `self.name`: Assigns the provided `name` to the object.

# %% [markdown]
# ## Adding and Modifying Attributes Dynamically 🔄

# %% [markdown]
# Python allows us to modify objects on the fly:

# %%
x.name = "Bob"
x.greet()  # Outputs: Hi, Bob!

x.age = 30  # Add a new attribute
print(x.age)  # Outputs: 30
# Out:
# Hi, Bob!
# 30

# %% [markdown]
# > ⚠️ Changes to an instance do not affect the class or other instances.

# %% [markdown]
# ## Inheritance 🌟

# %% [markdown]
# Inheritance allows us to create new classes based on existing ones, reusing their functionality:

# %%
class BaseClass:
    def show(self):
        print("I’m the base class.")

class DerivedClass(BaseClass):
    def greet(self):
        print("I inherit from the base class!")

obj = DerivedClass()
obj.show()  # Outputs: I’m the base class.
obj.greet()  # Outputs: I inherit from the base class!
# Out:
# I’m the base class.
# I inherit from the base class!

# %% [markdown]
# ## Operator Overloading 🎭

# %% [markdown]
# We can redefine how operators work with our objects by implementing special methods like `__add__`:

# %%
class Number:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        return self.value + other.value

x = Number(10)
y = Number(20)
print(x + y)  # Outputs: 30
# Out:
# 30

# %% [markdown]
# ## Docstrings in Classes 📝

# %% [markdown]
# Docstrings are a great way to document your classes and methods. They provide an explanation of what a class or method does and how it works. You add a docstring as a string inside the class or method:

# %%
class MyClass:
    """
    This is a sample class to demonstrate docstrings.
    Attributes:
        name (str): The name of the instance.
    Methods:
        greet(): Prints a greeting message.
    """

    def __init__(self, name):
        """
        Initializes the MyClass instance with a name.

        Args:
            name (str): The name of the instance.
        """
        self.name = name

    def greet(self):
        """
        Prints a greeting message.
        """
        print(f"Hello, {self.name}!")

# %% [markdown]
# You can view the docstring using the `help` function:

# %%
help(MyClass)

# %% [markdown]
# This will display the class and method documentation, making it easier for others (and future you!) to understand your code. 🧐

# %% [markdown]
# ## Summary 📚

# %% [markdown]
# - Classes allow us to bundle data (attributes) and behaviors (methods) together.
# - Use `__init__` to customize object creation.
# - Extend functionality using inheritance.
# - Overload operators to make objects behave like built-in types.
# - Document your code using docstrings for better readability and maintainability.

# %% [markdown]
# With these tools, you can create robust, reusable, and elegant code! 🌈✨

# %% [markdown]
# ## Exercises 🛠️📚

# %% [markdown]
# Here are some exercises to practice what you’ve learned:

# %% [markdown]
# ### Exercise 1: Create a Class with Methods

# %% [markdown]
# **Task:**
# 1. Define a class `Animal` with an attribute `name`.
# 2. Add a method `speak` that prints `"I am an animal."`.
# 3. Create an instance of the class and call the `speak` method.

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# class Animal:
#     def __init__(self, name):
#         self.name = name
#
#     def speak(self):
#         print("I am an animal.")
#
# x = Animal("Dog")
# x.speak()  # Outputs: I am an animal.
# ```
# </details>

# %% [markdown]
# ### Exercise 2: Create a Class with Inheritance

# %% [markdown]
# **Task:**
# 1. Define a base class `Shape` with a method `area` that returns 0.
# 2. Define a subclass `Rectangle` with attributes `width` and `height`.
# 3. Override the `area` method to return the area of the rectangle.

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# class Shape:
#     def area(self):
#         return 0
#
# class Rectangle(Shape):
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         return self.width * self.height
#
# rect = Rectangle(4, 5)
# print(rect.area())  # Outputs: 20
# ```
# </details>

# %% [markdown]
# ### Exercise 3: Operator Overloading

# %% [markdown]
# **Task:**
# 1. Create a class `Point` with attributes `x` and `y`.
# 2. Overload the `+` operator to add two points.

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# class Point:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
#     def __add__(self, other):
#         return Point(self.x + other.x, self.y + other.y)
#
#     def __str__(self):
#         return f"({self.x}, {self.y})"
#
# p1 = Point(1, 2)
# p2 = Point(3, 4)
# p3 = p1 + p2
# print(p3)  # Outputs: (4, 6)
# ```
# </details>

# %% [markdown]
# ### Exercise 4: Dynamic Attributes

# %% [markdown]
# **Task:**
# 1. Create a class `Person` with an attribute `name`.
# 2. Dynamically add an attribute `age` to an instance and print it.

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# class Person:
#     def __init__(self, name):
#         self.name = name
#
# p = Person("Alice")
# p.age = 25  # Add a new attribute
# print(p.age)  # Outputs: 25
# ```
# </details>
